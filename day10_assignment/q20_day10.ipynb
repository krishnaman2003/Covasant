# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1. Read
path = r"code\data\bikes.csv"
bikes = pd.read_csv(path, parse_dates=['Date'], dayfirst=True, index_col='Date')

# %%
bikes.head() #2. Check head
# Out:
#            Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# Date
# 2013-01-01      00:00       0    0      1      0     6        0        1
# 2013-01-02      00:00      69    0     13      0    18        0        2
# 2013-01-03      00:00      69    2     21      6    22        1        0
# 2013-01-04      00:00      80    0     22      4    16        0      125
# 2013-01-05      00:00      52    4     19      3    12        0       97
#
#             Totem_Laurier
# Date
# 2013-01-01              0
# 2013-01-02              0
# 2013-01-03              0
# 2013-01-04              0
# 2013-01-05              0

# %%
print(bikes.head())
# Out:
#            Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# Date
# 2013-01-01      00:00       0    0      1      0     6        0        1
# 2013-01-02      00:00      69    0     13      0    18        0        2
# 2013-01-03      00:00      69    2     21      6    22        1        0
# 2013-01-04      00:00      80    0     22      4    16        0      125
# 2013-01-05      00:00      52    4     19      3    12        0       97
#
#             Totem_Laurier
# Date
# 2013-01-01              0
# 2013-01-02              0
# 2013-01-03              0
# 2013-01-04              0
# 2013-01-05              0

# %%
bikes.describe() #3. Check summary statistics
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %%
print(bikes.describe())
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %%
#4. plot the daily attendance of two tracks, 'Berri1', 'PierDup'
bikes.index = pd.to_datetime(bikes.index)
plt.figure(figsize=(10, 4))
plt.plot(bikes.index, bikes['Berri1'], label='Berri1')
plt.plot(bikes.index, bikes['PierDup'], label='PierDup')
plt.xlabel('Date')
plt.ylabel('Number of Bikes')
plt.title('Daily attendance of Berri1 and PierDup')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#5. Check index, explore weekday_name attributes
bikes['Weekday_name'] = bikes.index.day_name()
print(bikes)
# Out:
#            Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# Date
# 2013-01-01      00:00       0     0      1      0     6        0        1
# 2013-01-02      00:00      69     0     13      0    18        0        2
# 2013-01-03      00:00      69     2     21      6    22        1        0
# 2013-01-04      00:00      80     0     22      4    16        0      125
# 2013-01-05      00:00      52     4     19      3    12        0       97
# ...               ...     ...   ...    ...    ...   ...      ...      ...
# 2013-09-14      00:00    2488  1494   1706   2911   979     1075     3277
# 2013-09-15      00:00    2243  1749   1417   2933  1804     1459     3623
# 2013-09-16      00:00    4206  2466   2799   5485  3272      855     4307
# 2013-09-17      00:00    5506  3153   3563   6626  3882     1485     5332
# 2013-09-18      00:00    1564  3330   1154   1803  4074     1759     1511
#
#             Totem_Laurier Weekday_name
# Date
# ...

# %%
#6. Get sum of all attendance as a function of the weekday
daily_total = bikes.sum(axis=1, numeric_only=True)
total_by_weekday = daily_total.groupby(bikes['Weekday_name']).sum()
total_by_weekday
# Out:
# Weekday_name
# Friday       640301
# Monday       662902
# Saturday     463944
# Sunday       466577
# Thursday     690471
# Tuesday      705161
# Wednesday    732606
# dtype: int64

# %%
#7. Display this in figure , what is the inference?
total_by_weekday.plot(kind='bar', figsize=(10,4))
plt.xlabel('Weekday')
plt.title('Total Attendance by Weekday')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1. Read and check data 
path = r"code\data\titanic_train.csv"
titanic = pd.read_csv(path)
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
print(titanic.head())
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
#2. Which gender survived more
survival_by_gender = titanic.groupby('sex')['survived'].mean()
print(survival_by_gender)
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby("sex")['survived'].sum().idxmax()
# Out:
# 'female'

# %%
#3. Does it depend on passenger class?
survival_pivot = titanic.pivot_table(
    index='pclass',
    columns='sex',
    values='survived',
    aggfunc='mean'
)
survival_percent = survival_pivot * 100
survival_percent
# Out:
# sex        female       male
# pclass
# 1       96.808511  36.885246
# 2       92.105263  15.740741
# 3       50.000000  13.544669

# %%
#4. can we see % of survival of each gender and pclass
survival_percent.plot(kind='bar', figsize=(8,5))
plt.xlabel('Passenger Class')
plt.ylabel('Survival Percentage (%)')
plt.title('Titanic Survival by Passenger Class and Gender')
plt.legend(title='Gender')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#1. Read and check data
path = r"code\data\federer.csv"
federer = pd.read_csv(path, parse_dates=['start date'])
federer.head()
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
print(federer.head())
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
#2. How many % of matches won by our player? ('winner')
player = 'Roger Federer'
total_matches = len(federer)
wins = (federer['winner'] == player).sum()
win_pct = wins / total_matches * 100
print(f"{player} won {win_pct:.4f}% of matches.")
# Out:
# Roger Federer won 82.4427% of matches.

# %%
'''3. Proportion of double faults wrt total points in each match 
This number is an indicator of the player's state of mind, his level of self-confidence, 
his willingness to take risks while serving, and other parameters.
columns:
'player1 double faults' and 'player1 total points total'
Display simple stats of above'''

federer['double_fault_rate'] = (
    federer['player1 double faults'] / federer['player1 total points total']
)
federer['double_fault_rate']
# Out:
# 0       0.019417
# 1       0.000000
# 2       0.020270
# 3       0.046154
# 4            NaN
#           ...
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: double_fault_rate, Length: 1179, dtype: float64

# %%
double_fault_stats = federer['double_fault_rate'].describe()
print(double_fault_stats)
# Out:
# count    1027.000000
# mean        0.012129
# std         0.010797
# min         0.000000
# 25%         0.004444
# 50%         0.010000
# 75%         0.018108
# max         0.060606
# Name: double_fault_rate, dtype: float64

# %%
#4. Average Win per surface
avg_win_surface = federer.groupby('surface')['winner'].apply(
    lambda winners: (winners == player).mean() * 100
)
print(avg_win_surface)
# Out:
# surface
# Indoor: Carpet    73.684211
# Indoor: Clay      83.333333
# Indoor: Hard      83.628319
# Outdoor: Clay     77.911647
# Outdoor: Grass    87.142857
# Outdoor: Hard     84.232365
# Name: winner, dtype: float64

# %%
'''5. Display the proportion of double faults as a function of the tournament date, 'start date' 
Trend: display average double faults in each year''' 

federer['start date'] = pd.to_datetime(federer['start date'], dayfirst=True)
federer['year'] = federer['start date'].dt.year
federer['proportion'] = (federer['player1 double faults'] /
                         federer['player1 total points total'])
avg_double = federer.groupby('year')['proportion'].mean()
plt.figure(figsize=(10, 6))
plt.plot(avg_double.index, avg_double.values, marker='o')
plt.title('Average Double Fault Proportion by Year')
plt.xlabel('Year')
plt.ylabel('Average Proportion of Double Faults')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
'''
D. Create two frequencies 5Hz and 50Hz sin signals 
Draw FFT components
'''
import numpy as np
import matplotlib.pyplot as plt

# Sampling parameters
Fs = 1000          # Sampling frequency
T = 1/Fs           # Sampling period 
t = np.arange(0, 1, T)  # Time vector of 1 second

# Generate sine waves
f1, f2 = 5, 50    # Frequencies in Hz
sig_5hz = np.sin(2 * np.pi * f1 * t)
sig_50hz = np.sin(2 * np.pi * f2 * t)

# Plot time domain signals
plt.figure(figsize=(12, 6))
plt.subplot(2,1,1)
plt.plot(t, sig_5hz)
plt.title('5 Hz Sine Wave')
plt.subplot(2,1,2)
plt.plot(t, sig_50hz)
plt.title('50 Hz Sine Wave')
plt.tight_layout()
plt.show()

# Compute FFT
n = len(sig_5hz)
fft_5hz = np.abs(np.fft.fft(sig_5hz)[:n//2])
fft_50hz = np.abs(np.fft.fft(sig_50hz)[:n//2])
freqs = np.fft.fftfreq(n, T)[:n//2]

# Plot frequency domain
plt.figure(figsize=(12, 6))
plt.subplot(2,1,1)
plt.stem(freqs, fft_5hz)
plt.title('FFT of 5 Hz Signal')
plt.xlim(0, 100)

plt.subplot(2,1,2)
plt.stem(freqs, fft_50hz)
plt.title('FFT of 50 Hz Signal')
plt.xlim(0, 100)
plt.tight_layout()
plt.show()

# %%
'''
E. Plotting normal random numbers
and show that addition of two Gaussian is Gaussian 
and addition of all is Gaussian
'''
#1. Generate random samples
n = 10000
x = np.random.randn(n)
y = np.random.randn(n)
z = x + y
w = x + y + np.random.randn(n)

# %%
z, w
# Out:
# (array([-1.52903564,  1.01606411,  2.84507562, ..., -0.69980474,
#         -1.67164292, -1.28919854]),
#  array([-0.54701995,  2.47236306,  2.84654299, ..., -1.78634731,
#         -1.86783222, -1.41281637]))

# %%
# 2. Plot histograms
dplt = plt.figure(figsize=(10, 6))
plt.hist(x, bins=50, alpha=0.5, label='X ~ N(0,1)')
plt.hist(y, bins=50, alpha=0.5, label='Y ~ N(0,1)')
plt.hist(z, bins=50, alpha=0.5, label='X+Y')
plt.hist(w, bins=50, alpha=0.5, label='X+Y+W')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Gaussian Sums')
plt.legend()
plt.tight_layout()
plt.show()
